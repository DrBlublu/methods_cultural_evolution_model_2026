# %% [markdown]
# IMPORTANT!
#
# Change the filename write away with your first and last name!
#
#
# Also, just in case, put your name here:
#
# - First name:
# - Last name:

# %% [markdown]
# # Instruction

# %% [markdown]
# In the current model, every individual always imitates the single best demonstrator. But in reality, learners might not always have access to the best individual.
#
# Modify *demography_model()* to add a parameter *q* representing the probability that a learner imitates the best individual. With probability *1 - q*, they instead pick a random individual from the population as their demonstrator.
#
# Run the population-size sweep for *q = 1.0, 0.75, 0.5, 0.25* and plot Δz̄ against N. How does relaxing the "copy the best" assumption affect N*? Is the effect stronger for simple or complex skills?

# %% [markdown]
# # Code

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def demography_model_prob(T_MAX, N, ALPHA, SIGMA, R_MAX):
    """
    Same as demography_model() but with a probabilistic learning rule.

    Parameters:
    - q: probability of imitating the best individual.
         With probability (1 - q), a random individual is chosen instead.
    """
    results = []

    for _ in range(R_MAX):
        z = np.ones(N)
        z_delta_bar = np.empty(T_MAX)

        for t in range(T_MAX):
            
            #---------------------------------------------------#
            # Here, copy the best if random < q
            # Copy at random if random > q
            demonstrator = ?
            #---------------------------------------------------#

            z_new = np.random.gumbel(
                loc=demonstrator - ALPHA,
                scale=SIGMA,
                size=N
            )
            z_delta_bar[t] = (z_new - z).mean()
            z = z_new

        # Average change in skill level across all timesteps for this run
        results.append(z_delta_bar.mean())

    # Return the grand mean across all runs
    return np.mean(results)

# %%
sizes = np.concatenate(([2], np.arange(100, 6101, 500)))
plt.figure(figsize=(8, 5))

#---------------------------------------------------#
# Generate an array for all values of q (1.0, 0.75, 0.5, 0.25)
# and run the model accordingly

qs = ?

for ?:
    results = [
        demography_model_prob(?) # Don't forget to add the q value to your function call and definition!
        for N in sizes
    ]
    plt.plot(sizes, results, label=f"q={q}") # This is important, keep it

#---------------------------------------------------#

plt.axhline(y=0, color="black", linewidth=1)
plt.xlabel("effective population size")
plt.ylabel("change in average skill level, delta z bar")
plt.legend(title="p(copy best)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Answer

# %% [markdown]
# You can write the answer to the questions here
